# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as mplt

# %%
data = pd.read_csv ('Dataset_heart rate_retail stores.csv')
#print(data)

# %%
data.head()
# Out:
#    cus_Id  age  gender   BMI  sleeping_time  sporting_activity_h_week  \
# 0       1   55  female  30.0            7.0                       2.0
# 1       2   25  female  18.4            9.0                       1.0
# 2       3   38    male  25.1            5.0                       3.0
# 3       4   21  female  22.6            8.0                       0.0
# 4       5   30  female  21.7           12.0                      10.0
#
#    daytime  outdoor_temperature shopping_cart    attendants  ... ex_max  \
# 0     noon                   23            no            no  ...    115
# 1     noon                   23           yes            no  ...    110
# 2     noon                   23            no            no  ...    116
# 3  evening                   23           yes        family  ...    146
# 4  evening                   23           yes  life partner  ...    111
#
#   ex_min hr_max max_time  hr_min  min_time  shopping_duration_In_minutes  \
# 0     71     95        8      72         4                            12
# 1     82    112       24      70        18                            26
# 2     74    115       18      75        20                            24
# 3     55    122       26      62        41                            46
# 4     44    120       39      61        20                            41
#
#    reaching_HRmax  age_groups  shopping_dur_min
# 0               0       54-62             06-28
# 1               0       18-26             06-28
# 2               0       36-44             06-28
# 3               0       18-26             29-51
# 4               1       27-35             29-51
#
# [5 rows x 25 columns]

# %%
data.columns = ['cus_Id', 'age', 'gender', 'BMI', 'sleeping_time', 'sporting_activity_h_week', 'daytime', 'outdoor_temperature',
'shopping_cart', 'attendants', 'shopping_frequency', 'cash_point', 'shopping_amount', 'weekday', 'smoking', 'ex_max'
, 'ex_min', 'hr_max', 'max_time', 'hr_min', 'min_time', 'shopping_duration_In_minutes', 'reaching_HRmax']

# %%
levels = np.linspace(min(data['age']), max(data['age']), 7)
intervals =["18-26", "27-35", "36-44", "45-53", "54-62","63+"]
data["age_groups"]=pd.cut(data["age"], levels, labels=intervals, include_lowest=True)

print(data["age_groups"])
# Out:
# 0      54-62
# 1      18-26
# 2      36-44
# 3      18-26
# 4      27-35
#        ...
# 160    45-53
# 161    18-26
# 162    54-62
# 163    27-35
# 164    27-35
# Name: age_groups, Length: 165, dtype: category
# Categories (6, object): [18-26 < 27-35 < 36-44 < 45-53 < 54-62 < 63+]

# %%
mplt.hist(data.age_groups)
mplt.show()

# %%
levels =np.linspace(min(data['shopping_duration_In_minutes']), max(data['shopping_duration_In_minutes']), 5)
intervals =["06-28", "29-51", "52-74", "75-98"]
data["shopping_dur_min"]=pd.cut(data["shopping_duration_In_minutes"], levels, labels=intervals, include_lowest=True)

print(data["shopping_dur_min"])
# Out:
# 0      06-28
# 1      06-28
# 2      06-28
# 3      29-51
# 4      29-51
#        ...
# 160    29-51
# 161    06-28
# 162    06-28
# 163    29-51
# 164    29-51
# Name: shopping_dur_min, Length: 165, dtype: category
# Categories (4, object): [06-28 < 29-51 < 52-74 < 75-98]

# %%
mplt.hist(data.shopping_dur_min)
mplt.show()

# %%
mplt.hist(data.gender)
mplt.show()

# %%
data.shopping_dur_min.describe()
# Out:
# count       165
# unique        4
# top       29-51
# freq         69
# Name: shopping_dur_min, dtype: object

# %%
data.groupby('age_groups')['shopping_duration_In_minutes'].mean()
# Out:
# age_groups
# 18-26    40.925000
# 27-35    34.108108
# 36-44    31.733333
# 45-53    36.954545
# 54-62    30.230769
# 63+      39.700000
# Name: shopping_duration_In_minutes, dtype: float64

# %%
data.groupby('age_groups')['BMI'].mean()
# Out:
# age_groups
# 18-26    24.552500
# 27-35    24.967568
# 36-44    25.510000
# 45-53    25.081818
# 54-62    25.592308
# 63+      26.690000
# Name: BMI, dtype: float64

# %%
data.groupby('age_groups')['BMI'].std()
# Out:
# age_groups
# 18-26    4.525426
# 27-35    4.433337
# 36-44    4.493854
# 45-53    2.405873
# 54-62    4.812560
# 63+      2.904192
# Name: BMI, dtype: float64

# %%
data.groupby('age_groups')['sporting_activity_h_week'].mean()
# Out:
# age_groups
# 18-26    3.137500
# 27-35    3.486486
# 36-44    2.366667
# 45-53    2.590909
# 54-62    2.076923
# 63+      3.500000
# Name: sporting_activity_h_week, dtype: float64

# %%
var1=data.sporting_activity_h_week
var2=data.shopping_duration_In_minutes
mplt.scatter(var1, var2)
mplt.show()

# %% [markdown]
# ### crosstab visualization

# %%
# representation of gender on outdoor temperature
pd.crosstab(data['outdoor_temperature'], data['gender'], margins = False).plot.bar();

# %%
# representation of gender on age groups
pd.crosstab(data['age_groups'], data['gender'], margins = False).iloc[:-1].plot.bar();

# %%
# representation of age on age smoking
pd.crosstab(data['age_groups'], data['smoking'], margins = False).iloc[:-1].plot.bar();

# %%
# create shopping duration group
levels = np.linspace(min(data['shopping_duration_In_minutes']), max(data['shopping_duration_In_minutes']), 7)
intervals =["6-21", "21-37", "37-52", "52-67", "67-82","82-98"]
group_shopping_duration = pd.cut(data["shopping_duration_In_minutes"], levels, labels=intervals, include_lowest=True)

# representation of age on shopping duration groups
pd.crosstab(group_shopping_duration, data['age_groups'], margins = False).iloc[:-1].plot.bar();

# %%
data_sel = data[data['shopping_duration_In_minutes'] > 46]
mplt.hist(data_sel.age_groups)
mplt.show()

# %%
data_sel.groupby('age_groups')['age_groups'].count()
# Out:
# age_groups
# 18-26    15
# 27-35     8
# 36-44     6
# 45-53     3
# 54-62     4
# 63+       3
# Name: age_groups, dtype: int64

# %%
var3=data_sel.shopping_duration_In_minutes
var4=data_sel.age
mplt.scatter(var3, var4)
mplt.show()

# %%
data.groupby('age_groups')['age_groups'].count()
# Out:
# age_groups
# 18-26    40
# 27-35    37
# 36-44    30
# 45-53    22
# 54-62    26
# 63+      10
# Name: age_groups, dtype: int64

# %%
pd.crosstab(data['age_groups'],data['shopping_amount'], margins = True)
# Out:
# shopping_amount  bag full  heavy  less  normal  All
# age_groups
# 18-26                   4     10    14      12   40
# 27-35                   6      4    13      14   37
# 36-44                   3      7    10      10   30
# 45-53                   3      3     6      10   22
# 54-62                   1      1    14      10   26
# 63+                     1      3     4       2   10
# All                    18     28    61      58  165

# %%
data.groupby('shopping_dur_min')['shopping_dur_min'].count()
# Out:
# shopping_dur_min
# 06-28    69
# 29-51    69
# 52-74    20
# 75-98     7
# Name: shopping_dur_min, dtype: int64

# %%
data_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 17 to 164
# Data columns (total 25 columns):
# cus_Id                          39 non-null int64
# age                             39 non-null int64
# gender                          39 non-null object
# BMI                             39 non-null float64
# sleeping_time                   39 non-null float64
# sporting_activity_h_week        39 non-null float64
# daytime                         39 non-null object
# outdoor_temperature             39 non-null int64
# shopping_cart                   39 non-null object
# attendants                      39 non-null object
# shopping_frequency              39 non-null object
# cash_point                      39 non-null object
# shopping_amount                 39 non-null object
# weekday                         39 non-null object
# smoking                         39 non-null int64
# ex_max                          39 non-null int64
# ex_min                          39 non-null int64
# hr_max                          39 non-null int64
# max_time                        39 non-null int64
# hr_min                          39 non-null int64
# min_time                        39 non-null int64
# shopping_duration_In_minutes    39 non-null int64
# reaching_HRmax                  39 non-null int64
# age_groups                      39 non-null category
# shopping_dur_min                39 non-null category
# dtypes: category(2), float64(3), int64(12), object(8)
# memory usage: 7.8+ KB

# %%
# cuss_ID, smokng and reaching_HRMax are categorical values, so drop them for corr calculation
new_data = data.drop(['cus_Id', 'smoking', 'reaching_HRmax'], axis=1)


new_data.corr()
# Out:
#                                    age       BMI  sleeping_time  \
# age                           1.000000  0.110255      -0.189095
# BMI                           0.110255  1.000000       0.033668
# sleeping_time                -0.189095  0.033668       1.000000
# sporting_activity_h_week     -0.118630 -0.043937       0.010906
# outdoor_temperature           0.006607  0.037913      -0.179223
# ex_max                       -0.518141  0.012990      -0.032945
# ex_min                       -0.134267  0.109906      -0.075329
# hr_max                       -0.204124 -0.033803      -0.058156
# max_time                     -0.026141  0.003950       0.145284
# hr_min                       -0.023922  0.182111      -0.099453
# min_time                     -0.084080 -0.070108       0.143876
# shopping_duration_In_minutes -0.097265  0.009633       0.205745
#
#                               sporting_activity_h_week  outdoor_temperature  \
# age                                          -0.118630             0.006607
# BMI                                          -0.043937             0.037913
# sleeping_time                                 0.010906            -0.179223
# sporting_activity_h_week                      1.000000            -0.017623
# outdoor_temperature                          -0.017623             1.000000
# ex_max                                       -0.005551             0.158481
# ex_min                                       -0.130944             0.264276
# hr_max                                       -0.067024            -0.048422
# max_time                                     -0.046103            -0.044346
# hr_min                                       -0.073751             0.201904
# min_time                                     -0.066015            -0.177809
# shopping_duration_In_minutes                 -0.100318            -0.137691
#
#                                 ex_max    ex_min    hr_max  max_time  \
# age                          -0.518141 -0.134267 -0.204124 -0.026141
# BMI                           0.012990  0.109906 -0.033803  0.003950
# sleeping_time                -0.032945 -0.075329 -0.058156  0.145284
# sporting_activity_h_week     -0.005551 -0.130944 -0.067024 -0.046103
# outdoor_temperature           0.158481  0.264276 -0.048422 -0.044346
# ex_max                        1.000000  0.514633  0.363440 -0.088448
# ex_min                        0.514633  1.000000  0.276460 -0.039384
# hr_max                        0.363440  0.276460  1.000000  0.176621
# max_time                     -0.088448 -0.039384  0.176621  1.000000
# hr_min                        0.383921  0.512019  0.165301 -0.268129
# min_time                     -0.114780 -0.099152  0.033259  0.446488
# shopping_duration_In_minutes -0.074393 -0.086728  0.204211  0.711547
#
#                                 hr_min  min_time  shopping_duration_In_minutes
# age                          -0.023922 -0.084080                     -0.097265
# BMI                           0.182111 -0.070108                      0.009633
# sleeping_time                -0.099453  0.143876                      0.205745
# sporting_activity_h_week     -0.073751 -0.066015                     -0.100318
# outdoor_temperature           0.201904 -0.177809                     -0.137691
# ex_max                        0.383921 -0.114780                     -0.074393
# ex_min                        0.512019 -0.099152                     -0.086728
# hr_max                        0.165301  0.033259                      0.204211
# max_time                     -0.268129  0.446488                      0.711547
# hr_min                        1.000000 -0.236258                     -0.329534
# min_time                     -0.236258  1.000000                      0.511929
# shopping_duration_In_minutes -0.329534  0.511929                      1.000000

# %%
attributes = ["age", "BMI", "sleeping_time", "sporting_activity_h_week", "outdoor_temperature", "ex_max",
"ex_min", "hr_max", "max_time", "hr_min", "min_time", "shopping_duration_In_minutes", ]

x=pd.plotting.scatter_matrix(new_data[attributes], figsize=(12,8))

# %%
# plot distribution of feature variables

# %matplotlib inline
import matplotlib.pyplot as plt
new_data.hist(bins=50, figsize=(20,15))
plt.show()
